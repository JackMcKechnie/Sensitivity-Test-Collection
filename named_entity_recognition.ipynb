# %%
import glob
import pandas as pd
import os
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
import numpy as np
import re
import seaborn as sns
import matplotlib.patches as mpatches
import spacy 
nlp = spacy.load('en_core_web_sm')

# %%
# Utility functions

def filenames_from_cat(top,second):
    cats_globs = glob.glob('./*/*/*.cats')
    matches = []
    for g in cats_globs:
        with open(g) as file:
            for line in file:
                line = line.split()[0]
                line = line.split(",")
                if int(line[0]) == top and int(line[1]) == second:
                    dir = os.path.basename(g)
                    filename = os.path.splitext(dir)[0]
                    matches.append(filename)
    
    return matches

def print_email_from_filename(filename):
    full_filename = glob.glob('./*/*/' + str(filename) + '.txt')
    with open(full_filename[0]) as file:
        for line in file:
            print(line)

def save_email_from_filename(filename):
    full_filename = glob.glob('./*/*/' + str(filename) + '.txt')
    email_contents = ""
    with open(full_filename[0]) as file:
        for line in file:
            email_contents = email_contents + line
    return email_contents

def save_all_from_cat(primary, secondary):
    filenames = filenames_from_cat(primary, secondary)
    contents = ""
    for file in filenames:
        contents = contents + save_email_from_filename(file)
        contents = contents + "\n" + ("*" * 100) + "\n\n"
    return contents

def list_all_filenames():
    globs = glob.glob('./*/*/*.cats')
    filenames = []
    for file in globs:
        filenames.append(os.path.splitext(os.path.basename(file))[0])
    return filenames

def length_of_email_from_filename(filename):
    email_text = save_email_from_filename(filename)
    tokenised = word_tokenize(email_text)
    return len(tokenised)

def number_of_recipients(filename):
    addresses = []
    contents = save_email_from_filename(filename)
    contents = contents.split("\n")
    for line in contents:
        if line.startswith("To:"):
            addresses.append(re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+", line))
    
    return len([j for sub in addresses for j in sub])

def get_sender_from_filename(filename):
    addresses = []
    contents = save_email_from_filename(filename)
    contents = contents.split("\n")
    for line in contents:
        if line.startswith("From:"):
            addresses.append(re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+", line))
    
    return [j for sub in addresses for j in sub][0]

# %%
# Partition emails into sensitive and non-sensitive
sensitive_filenames = []
# Assume 'Purely personal' and 'Personal but in a professional context' are the sensitive categories
sensitive_filenames.append(filenames_from_cat(1,2))
sensitive_filenames.append(filenames_from_cat(1,3))
# Flatten the list
sensitive_filenames = [j for sub in sensitive_filenames for j in sub]
# Remove duplicates - 3 emails are counted in both categories
sensitive_filenames = list(dict.fromkeys(sensitive_filenames))

non_sensitive_filenames = []
for name in list_all_filenames():
    if name not in sensitive_filenames:
        non_sensitive_filenames.append(name)

# %%
def show_ents(doc): 
    ents =  []
    if doc.ents: 
        for ent in doc.ents: 
            ents.append([ent.text,ent.label_])
    else: 
        print('No named entities found.')
        
    return ents

# %%
def get_entities(filenames):
    ents = []
    
    for filename in filenames:
        email = save_email_from_filename(filename)
        email = nlp(email.replace('\n',' '))
        ents.append(show_ents(email))

    return ents

# %%
sensitive_entities = get_entities(sensitive_filenames)
non_sensitive_entities = get_entities(non_sensitive_filenames)

# %%
named_people = dict()

for email in sensitive_entities:
    for entity in email:
        if entity[1] == "PERSON":
            if entity[0] not in named_people:
                named_people[entity[0]] = 1
            else:
                named_people[entity[0]] += 1

print({k: v for k, v in sorted(named_people.items(), key=lambda item: item[1],reverse=True)})
# Out:
# {'Davis': 114, 'Vince J\\Sent Items X-Origin': 87, 'Steven J Kean X-To': 82, 'Williams': 63, 'Steven J Kean/NA': 52, 'Vince': 49, 'Miller': 45, 'j.kaminski@enron.com To': 44, 'RMR': 42, 'Gray Davis': 37, 'SoCal Ed': 33, 'Steven J Kean/HOU': 26, 'Richard Shapiro': 24, 'Hebert': 24, 'Reliant': 24, 'Crenshaw': 22, 'Jeff Dasovich': 19, 'Williams Energy': 18, 'Jeff': 16, 'Massey': 16, 'Edison': 15, 'Steve': 14, 'Shirley': 14, 'William': 13, 'Ehud I. Ronn': 11, 'Bush': 10, 'Leno': 10, 'Sarah Novosel': 10, 'Kean-S X-FileName': 9, 'Hudler': 9, 'Jessica Berthold': 9, 'Jason Leopold': 9, 'Debra Bowen': 9, 'Fichera': 9, 'Alamitos': 9, 'Harrigan': 9, 'Reilly': 9, 'Burrito': 8, 'Lynch': 8, 'Edward Krapels': 8, 'Lieberman': 7, 'Kathy Wedig': 7, 'Steve & Melissa Kean': 7, 'Rick': 7, 'Pozdrawiam': 7, 'Linda Robertson': 7, 'Austin': 7, 'TX': 7, 'Mark': 7, 'Steve Kean': 7, 'Ken': 7, 'Joe Lieberman': 6, 'Phil Kean': 6, 'Philippe': 6, 'Steven J.\\Sent Items X-Origin': 6, 'Sarah-Joy': 6, 'Dale Clark': 6, 'Peter Goebel': 6, 'Vince  -----Original Message-----': 6, 'Stuart III': 6, 'Lu': 6, 'Frank Wolak': 6, 'Karen Denne/Corp/Enron@ENRON': 6, 'Stockdale': 6, 'Vince Kaminski': 6, 'Kim': 6, 'Linda': 6, 'Dave': 6, 'Bowring': 6, 'Stern': 6, 'David Sokol': 6, 'Ed': 6, 'Mitchell Landsberg': 6, 'Charles Robinson': 6, 'Kathleen Connell': 6, 'Jay Lawrence': 6, 'Cal-ISO': 6, 'Harry Allen': 6, 'Michaud': 6, 'Clinton': 5, 'James D Steffes': 5, 'Robert Kean': 5, 'Rob': 5, 'Bill': 5, 'Conti': 5, 'Dzien Dobry': 5, 'wszystkie': 5, 'Warszawy - LOT': 5, 'JFK': 5, 'Patrick Tucker': 5, 'Maureen': 5, 'Loretta Lynch': 5, 'Jan Smutny-Jones': 5, 'Jim': 5, 'Kate': 5, 'Shirley Subject': 5, 'Rice': 5, 'w.r.t': 5, 'Duane Seppi': 5, 'Peter Nance': 5, 'Renee Toft Sat': 5, 'Ehud  ': 5, 'Jack S. Josey Professor': 5, 'Vasant': 5, 'Vince J   Sent:': 5, 'Maureen McVicker X-cc': 4, 'Kevin Hannon': 4, 'Laura': 4, 'Kean': 4, 'Sherri Sera': 4, 'David Cox': 4, 'Sherri Sera                           ': 4, '\\(E-mail\\': 4, 'Greg Smith': 4, 'Christopher Culberson': 4, 'Morgan': 4, 'Wade Cline': 4, 'Kevin Scott': 4, '\\JSKILLIN': 4, 'JSKILLIN': 4, 'Vince J. Kaminski/ENRON@enronXgate': 4, 'Jane Blizzard': 4, 'Dzien dobry Panu': 4, 'Paul Kaufman': 4, 'Matt Harris': 4, 'Tanya': 4, 'Krishnarao': 4, 'Amen Burrito': 4, 'Gary Ackerman': 4, 'Herr': 4, 'Dan Douglass': 4, 'Kahn': 4, 'John': 4, 'Joe': 4, 'Steven J  Kean/NA': 4, 'Rebecca McDonald': 4, 'Brown': 4, 'Harry Kingerski': 4, 'Ose': 4, 'Balson': 4, 'Joanna Vidal': 4, 'Ehud': 4, 'Schoenemann Resume Mime-Version': 4, 'Schoenemann Resume': 4, 'Kevin': 3, 'Gary': 3, 'Hillary': 3, 'Leslie Lawner/NA': 3, 'Ben Glisan': 3, 'Michael Brown/NA': 3, 'Wade': 3, 'Stan Horton': 3, 'Sherri': 3, 'Elsa': 3, 'Karen Reiman': 3, 'Steven J.\\Sent Items': 3, 'Shirley   Sent:': 3, 'Krishnarao Pinnamaneni': 3, 'Karasinski': 3, 'Vince  P.S.': 3, 'Karen Denne': 3, 'Greg Pyle': 3, 'Bill Lovejoy': 3, 'Jennifer Medcalf': 3, 'Peter': 3, 'Email': 3, '-0700': 3, 'Cindy Cc': 3, 'Maureen Raymond-Castaneda   ': 3, 'Thuraisingham': 3, 'Huntco': 3, 'Walter Coffer': 3, 'Tamarchenko': 3, 'David Parquet': 3, 'Joe Hartsoe/Corp/Enron@ENRON': 3, 'James D Steffes/HOU': 3, 'Kenneth': 3, 'Beth': 3, 'Karen Denne X-cc': 3, 'Lay': 3, 'Greg': 3, 'Laura Schwartz': 3, 'Mark Palmer/Corp/Enron@ENRON': 3, 'James D  Steffes/HOU': 3, 'Richard Shapiro X-cc': 3, 'Bill Massey': 3, 'Steven J Kean': 3, 'Cynthia Sandherr/Corp/Enron@ENRON': 3, 'Linda Breathitt': 3, 'Andy': 3, 'ECT@ECT \t\t ': 3, 'Linda Robertson/NA': 3, 'Rick Shapiro Presentation': 3, 'Suzanne Nimocks/HOU': 3, 'Jeff Gerth': 3, 'Joseph Kahn': 3, "Jeff Gerth's": 3, 'Bill Clinton': 3, 'JEFF GERTH': 3, 'JOSEPH KAHN       ': 3, 'Curt Hebert Jr.': 3, 'Scott       Miller': 3, 'William       Massey': 3, 'Franklin D.': 3, 'Roosevelt       ': 3, 'Pat       Wood': 3, 'Joseph Bowring': 3, 'Ron Rattey': 3, 'Gary Stern': 3, 'Daniel Larcamp': 3, 'Rob       Doty': 3, 'Kevin Kelly': 3, 'Paula Hall Collins': 3, 'Collins': 3, 'Michael P. Morrell': 3, 'Kirk Morg ...

# %%
named_people = dict()

for email in non_sensitive_entities:
    for entity in email:
        if entity[1] == "PERSON":
            if entity[0] not in named_people:
                named_people[entity[0]] = 1
            else:
                named_people[entity[0]] += 1

print({k: v for k, v in sorted(named_people.items(), key=lambda item: item[1],reverse=True)})
# Out:
# {'Davis': 2995, 'Bush': 1181, 'Steven J Kean X-To': 905, 'Gray Davis': 763, 'Steven J Kean/NA': 735, 'the=20': 442, 'Williams': 395, 'Richard Shapiro': 346, 'Jeff Dasovich': 309, 'Steven J Kean/HOU': 244, 'James D Steffes': 244, 'Jeff': 214, 'Ken': 146, 'Reliant': 139, 't= o=20': 135, 'y=20': 132, 'l=20': 129, 'Steve': 128, 't=': 127, 'Ken Lay': 124, 'Linda': 121, 'Steve Maviglio': 120, 'James D.': 117, 'Maureen McVicker X-cc': 114, 'Richard': 111, 'Mark Palmer': 110, 'Linda Robertson': 109, 'Abraham': 108, 'Clinton': 108, 'Lockyer': 107, 'Massey': 103, 'Sarah Novosel': 102, 'to=20': 102, 'Sarah': 102, 'Paul Kaufman': 100, 'Lynch': 99, 'Cheney': 98, 'Robertson': 98, 'Frank Wolak': 97, 'Alan Comnes': 97, 'Dianne Feinstein': 97, 'Susan J Mara': 95, 's=20': 95, 'Lay': 95, 'Shapiro': 95, 'Mark Palmer/Corp/Enron@ENRON': 93, 'Steven J Kean': 93, 'Elizabeth Linnell': 92, 'Karen Denne': 90, 'Wood': 88, 'Gary Ackerman': 81, 'Cal-ISO': 80, 'Watson': 80, 'Joe Hartsoe': 77, 'Edison': 77, 'Ray Alvarez': 77, 'Vince J\\Sent Items X-Origin': 75, 'Mona L Petrochko': 72, 'have=': 72, 'Karen Denne/Corp/Enron@ENRON': 71, 'Loretta Lynch': 71, 'Richard B Sanders': 71, 'Miller': 69, 'Christi L.': 69, 'SoCal Ed': 69, 'Hebert': 68, 'n=20': 68, 'Susan': 68, 'Joe': 67, 'Vince': 67, 'Mark': 65, 'Smith': 65, 'Tom Briggs': 64, 'Dave': 64, 'Frank': 63, 'Dick Cheney': 63, 'Mike': 63, 'Susan J Mara/NA': 62, 'Feinstein': 62, 'Ray': 61, 'David Lazarus': 61, 'Carrie Peyton': 61, 'Rick': 61, 'John': 61, 'Alan': 59, 'Spencer Abraham': 58, 'Alvarez': 58, 'Maureen McVicker/NA': 57, 'Kean-S X-FileName': 57, 'Jeff Skilling': 56, 'Dale Kasler': 56, 'Dunn': 55, 'Joseph Alamo': 55, 'Kenneth Lay': 54, 'Janel Guerrero': 54, 'Debra Bowen': 54, 'Steve Kean': 54, 'Sandra McCubbin': 53, 'tom.briggs@enron.com': 53, 'Jan Smutny-Jones': 52, 'Fri': 52, 'Harry Kingerski': 51, 'HOU': 50, 'Mike Roan': 50, 'Kean': 50, 'Andrew Morrison': 49, 'Peggy Mahoney': 49, 'John Sherriff': 49, 'RMR': 48, 'Lieberman': 48, 'Chris': 48, 'Burton': 47, 'John Neslage': 47, 'Ron Low': 47, 'Treasurer Phil Angelides': 47, 'Roger Yang': 46, 'Reliant Energy': 46, 'nd=20': 46, 'Shortridge': 46, 'Battin': 46, 'Fred Keeley': 45, 'Jim': 44, 'Bowen': 44, 'Dabhol': 44, 'Pat': 44, 'Glynn': 43, 'Peggy Mahoney/HOU': 43, 'Rob Bradley': 43, 'Mark Frevert': 42, 'Tim Belden': 42, 'Tim Belden/HOU': 42, 'Richard Wheatley': 42, 'Gray': 42, 'News=20': 42, 'Tom': 42, 'Michael': 42, 'Mark Schroeder': 41, "Nicholas O'Day": 41, 'as=20': 41, 'Dan Walters': 41, 'j.kaminski@enron.com To': 41, 'Crenshaw': 41, 'Bill Lockyer': 40, 'Michael Shames': 40, 'Fichera': 40, 'Shelley Corman': 40, 'Dasovich': 40, 'Greg Whalley': 39, 'Janet Butler': 39, 'Peter Styles': 39, 'Dennis Montali': 39, 'Thomas': 39, 'Galiteva': 39, 'Kathleen Connell': 39, 'Pro Tem': 38, 'Jones': 38, 'Michelle': 38, 'Barton': 38, 'James D Steffes/HOU': 37, 'Frank A. Wolak': 37, 'Mary Hain/HOU': 37, 'Bill Jones': 37, 'Writers=20  ?': 37, 'Cynthia': 37, 'Steven J  Kean/NA': 36, 'ECT@ECT \t\t ': 36, 'Carin Nersesian': 36, 'Bill': 35, 'John Burton': 35, 'Metcalf': 35, 'Bryan Seyfried': 35, 'Kevin': 35, 'Jennifer': 35, 'Donna': 35, 'Jeffrey': 35, 'Mark Haedicke': 34, 'Linda Robertson/NA': 34, 'John Nelson': 34, 'Jsteffe': 34, 'Shapiro-R X-FileName:': 34, 'Elizabeth': 33, 'Jason Leopold': 33, 'Dan Leff/HOU': 33, 'Vicki Sharp': 33, 'Ann M Schmidt': 33, 'Alex Parsons': 33, 'Greg': 33, 'Chuck Watson': 33, 'Lodi': 33, 'Lee': 32, 'Nettie Hoge': 32, 'Bcc': 32, 'Tom Williams': 32, 'Stella Chan': 32, 'John Shelk': 32, 'Wagner': 32, 'Nancy Rivera Brooks': 31, 'Jeannie Mandelker': 31, 'Lysa Akin': 31, 'Lora Sullivan': 31, 'Barry': 31, 'Yeung': 31, 'Jim Battin': 31, 'Shirley': 31, 'Florio': 30, 'Paula Hall-Collins': 30, 'John Bryson': 30, 'George W. Bush': 30, 'Robert C Williams': 30, 'Markus Fiala': 30, 'Michael R Brown': 30, 'Shirley A Hudler': 30, 'Perrino': 30, 'Items X-Origin': 30, 'Tim': 30, 'Moler': 30, 'Allen': 29, 'Miyung Buster X-To': 29, 'Joseph Fichera': 29, 'Bush=20': 29,  ...
